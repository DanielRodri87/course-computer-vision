# %%
from pandas import DataFrame
import numpy as np
import pandas as pd

# %%
# Cria um dicionário
dados = {'Estado': ['Santa Catarina', 'Rio de Janeiro', 'Tocantins', 'Bahia', 'Minas Gerais'], 
         'Ano': [2004, 2005, 2006, 2007, 2008], 
         'Taxa Desemprego': [1.5, 1.7, 1.6, 2.4, 2.7]}

# %%
df = DataFrame(dados)

# %%
df.head()
# Out:
#            Estado   Ano  Taxa Desemprego
# 0  Santa Catarina  2004              1.5
# 1  Rio de Janeiro  2005              1.7
# 2       Tocantins  2006              1.6
# 3           Bahia  2007              2.4
# 4    Minas Gerais  2008              2.7

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# Que tal reorganizar as colunas:
df = DataFrame(dados, columns=['Estado', 'Taxa Desemprego', 'Ano'])

df.head()
# Out:
#            Estado  Taxa Desemprego   Ano
# 0  Santa Catarina              1.5  2004
# 1  Rio de Janeiro              1.7  2005
# 2       Tocantins              1.6  2006
# 3           Bahia              2.4  2007
# 4    Minas Gerais              2.7  2008

# %%
# Perceba que taquei uma nova coluna e mexi no index
df = DataFrame(dados,
               columns=['Estado', 'Taxa Desemprego', 'Ano', 'Coluna nova'],
                index=['1°', '2°', '3°', '4°', '5°']
               )

df
# Out:
#             Estado  Taxa Desemprego   Ano Coluna nova
# 1°  Santa Catarina              1.5  2004         NaN
# 2°  Rio de Janeiro              1.7  2005         NaN
# 3°       Tocantins              1.6  2006         NaN
# 4°           Bahia              2.4  2007         NaN
# 5°    Minas Gerais              2.7  2008         NaN

# %%
df.values
# Out:
# array([['Santa Catarina', 1.5, 2004, nan],
#        ['Rio de Janeiro', 1.7, 2005, nan],
#        ['Tocantins', 1.6, 2006, nan],
#        ['Bahia', 2.4, 2007, nan],
#        ['Minas Gerais', 2.7, 2008, nan]], dtype=object)

# %%
df.dtypes
# Out:
# Estado              object
# Taxa Desemprego    float64
# Ano                  int64
# Coluna nova         object
# dtype: object

# %%
df.columns
# Out:
# Index(['Estado', 'Taxa Desemprego', 'Ano', 'Coluna nova'], dtype='object')

# %%
# Exibindo apenas uma coluna do DataFrame:
df[['Ano', 'Taxa Desemprego']]
# Out:
#      Ano  Taxa Desemprego
# 1°  2004              1.5
# 2°  2005              1.7
# 3°  2006              1.6
# 4°  2007              2.4
# 5°  2008              2.7

# %%
df.index
# Out:
# Index(['1°', '2°', '3°', '4°', '5°'], dtype='object')

# %%
# Posso pegar um item pelo indice
# axis = eixo 0
df.filter(items=['3°'], axis=0)
# Out:
#        Estado  Taxa Desemprego   Ano Coluna nova
# 3°  Tocantins              1.6  2006         NaN

# %% [markdown]
# ## Usando Numpy e Pandas

# %%
df.head()
# Out:
#             Estado  Taxa Desemprego   Ano Coluna nova
# 1°  Santa Catarina              1.5  2004         NaN
# 2°  Rio de Janeiro              1.7  2005         NaN
# 3°       Tocantins              1.6  2006         NaN
# 4°           Bahia              2.4  2007         NaN
# 5°    Minas Gerais              2.7  2008         NaN

# %%
df.dtypes
# Out:
# Estado              object
# Taxa Desemprego    float64
# Ano                  int64
# Coluna nova         object
# dtype: object

# %%
# Só retornou as colunas do tipo númerico, o que é o obvio a acontecer mesmo
df.describe()
# Out:
#        Taxa Desemprego          Ano
# count         5.000000     5.000000
# mean          1.980000  2006.000000
# std           0.535724     1.581139
# min           1.500000  2004.000000
# 25%           1.600000  2005.000000
# 50%           1.700000  2006.000000
# 75%           2.400000  2007.000000
# max           2.700000  2008.000000

# %%
# Quero saber onde tem valores ausente
df.isna()
# Out:
#     Estado  Taxa Desemprego    Ano  Coluna nova
# 1°   False            False  False         True
# 2°   False            False  False         True
# 3°   False            False  False         True
# 4°   False            False  False         True
# 5°   False            False  False         True

# %%
df["Coluna nova"].isna()
# Out:
# 1°    True
# 2°    True
# 3°    True
# 4°    True
# 5°    True
# Name: Coluna nova, dtype: bool

# %%
df["Coluna nova"] = np.arange(5.)

# %%
df.head()
# Out:
#             Estado  Taxa Desemprego   Ano  Coluna nova
# 1°  Santa Catarina              1.5  2004          0.0
# 2°  Rio de Janeiro              1.7  2005          1.0
# 3°       Tocantins              1.6  2006          2.0
# 4°           Bahia              2.4  2007          3.0
# 5°    Minas Gerais              2.7  2008          4.0

# %%
df.isna()
# Out:
#     Estado  Taxa Desemprego    Ano  Coluna nova
# 1°   False            False  False        False
# 2°   False            False  False        False
# 3°   False            False  False        False
# 4°   False            False  False        False
# 5°   False            False  False        False

# %%
df.describe()
# Out:
#        Taxa Desemprego          Ano  Coluna nova
# count         5.000000     5.000000     5.000000
# mean          1.980000  2006.000000     2.000000
# std           0.535724     1.581139     1.581139
# min           1.500000  2004.000000     0.000000
# 25%           1.600000  2005.000000     1.000000
# 50%           1.700000  2006.000000     2.000000
# 75%           2.400000  2007.000000     3.000000
# max           2.700000  2008.000000     4.000000

# %% [markdown]
# ## Slicing do Pandas

# %%
df
# Out:
#             Estado  Taxa Desemprego   Ano  Coluna nova
# 1°  Santa Catarina              1.5  2004          0.0
# 2°  Rio de Janeiro              1.7  2005          1.0
# 3°       Tocantins              1.6  2006          2.0
# 4°           Bahia              2.4  2007          3.0
# 5°    Minas Gerais              2.7  2008          4.0

# %%
# Podemos ver que o último entra no resultado, ele não é exlucivo
df["1°":"2°"]
# Out:
#             Estado  Taxa Desemprego   Ano  Coluna nova
# 1°  Santa Catarina              1.5  2004          0.0
# 2°  Rio de Janeiro              1.7  2005          1.0

# %%
df[df['Taxa Desemprego'] < 2]
# Out:
#             Estado  Taxa Desemprego   Ano  Coluna nova
# 1°  Santa Catarina              1.5  2004          0.0
# 2°  Rio de Janeiro              1.7  2005          1.0
# 3°       Tocantins              1.6  2006          2.0

# %%
# Lembre, 1 coluna = []
# Duas colunas ou mais = [[]]

df['Ano']
# Out:
# 1°    2004
# 2°    2005
# 3°    2006
# 4°    2007
# 5°    2008
# Name: Ano, dtype: int64

# %%
df[['Estado', 'Ano']]
# Out:
#             Estado   Ano
# 1°  Santa Catarina  2004
# 2°  Rio de Janeiro  2005
# 3°       Tocantins  2006
# 4°           Bahia  2007
# 5°    Minas Gerais  2008

# %% [markdown]
# ## Preenchendo Valores Ausentes em DataFrames do Pandas
#
# A função fillna() é usada para preencher os valores ausentes. A função oferece muitas opções. Podemos usar um valor específico, uma função agregada (por exemplo, média) ou o valor anterior ou seguinte.
#
# Para esse exemplo usaremos a moda, a estatística que representa o valor que aparece mais vezes em uma variável.

# %%
novo_df = pd.read_csv("dataset.csv")

# %%
# Exibo os 5 primeiros valores
novo_df.head(5)
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         NaN
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         NaN
# ...

# %%
# Quantos valores NaN temos em cada coluna? O sum responde para gente
novo_df.isna().sum()
# Out:
# ID_Pedido       0
# Data_Pedido     0
# ID_Cliente      0
# Segmento        0
# Pais            0
# Regiao          0
# ID_Produto      0
# Categoria       0
# Nome_Produto    0
# Valor_Venda     0
# Quantidade      2
# dtype: int64

# %%
# Vamos extrair a moda da coluna Quantidade
# value_counts = Lista com os valores que mais de respetem
# Retorno o primeiro valor, o que mais se repetiu em index[0]
moda = novo_df['Quantidade'].value_counts().index[0]

moda
# Out:
# 3.0

# %%
# Agora vamos preencher os valores ausentes com a moda, o fillna = preencher valores nan
# inplace = é para garantir que ele faça a alteração no próprio dataframe
novo_df['Quantidade'].fillna(value = moda, inplace=True)

# %%
# Verificando
novo_df.isna().sum()
# Out:
# ID_Pedido       0
# Data_Pedido     0
# ID_Cliente      0
# Segmento        0
# Pais            0
# Regiao          0
# ID_Produto      0
# Categoria       0
# Nome_Produto    0
# Valor_Venda     0
# Quantidade      0
# dtype: int64

# %%
novo_df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...

# %% [markdown]
# ## Query (Consulta) de Dados no DataFrame do Pandas
#
# Com o Pandas criamos dataframes, que são essencialmente tabelas. Como tal, podemos fazer consultas, ou simplesmente queries. E para isso usamos o método query(). Veja o exemplo abaixo:

# %%
novo_df['Valor_Venda'].describe()
# Out:
# count     9994.000000
# mean       229.858001
# std        623.245101
# min          0.444000
# 25%         17.280000
# 50%         54.490000
# 75%        209.940000
# max      22638.480000
# Name: Valor_Venda, dtype: float64

# %%
# O professor fez assim:
novo_df.Valor_Venda.describe()
# Out:
# count     9994.000000
# mean       229.858001
# std        623.245101
# min          0.444000
# 25%         17.280000
# 50%         54.490000
# 75%        209.940000
# max      22638.480000
# Name: Valor_Venda, dtype: float64

# %%
# Quero fazer uma consulta de valores entre 229 e 1000
values229_1000 = novo_df.query('229 < Valor_Venda < 1000')


values229_1000.head()
values229_1000.describe()
# Out:
#        Valor_Venda   Quantidade
# count  1894.000000  1894.000000
# mean    471.347406     4.340549
# std     202.048123     2.302453
# min     229.544000     1.000000
# 25%     302.376000     3.000000
# 50%     418.308000     4.000000
# 75%     600.558000     5.000000
# max     999.980000    14.000000

# %%
# Quero apenas quantidafes acima de 3

quant3 = novo_df.query("Quantidade > 3.0")

quant3.head(15)
# Out:
#          ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 3   US-2015-108966  2015-10-11   SO-20335     Consumer  United States
# 5   CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 6   CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 7   CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 9   CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 10  CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 11  CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 14  US-2015-118983  2015-11-22   HP-14815  Home Office  United States
# 16  CA-2014-105893  2014-11-11   PK-19075     Consumer  United States
# 20  CA-2014-143336  2014-08-27   ZD-21925     Consumer  United States
# 21  CA-2016-137330  2016-12-09   KB-16585    Corporate  United States
# 22  CA-2016-137330  2016-12-09   KB-16585    Corporate  United States
# ...

# %% [markdown]
# ## Verificando a ocorrencia de valores diversos valores em uma coluna

# %%
novo_df.shape
# Out:
# (9994, 11)

# %%
# Filtrando vendas, cujo a quantidade é igual a 5, 7, 9 ou 11
novo_df[novo_df['Quantidade'].isin([5,7,9,11])]
# Out:
#            ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 3     US-2015-108966  2015-10-11   SO-20335     Consumer  United States
# 5     CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 9     CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 10    CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 14    US-2015-118983  2015-11-22   HP-14815  Home Office  United States
# ...              ...         ...        ...          ...            ...
# 9974  US-2016-103674  2016-12-06   AP-10720  Home Office  United States
# 9977  US-2016-103674  2016-12-06   AP-10720  Home Office  United States
# 9981  CA-2017-163566  2017-08-03   TB-21055     Consumer  United States
# 9982  US-2016-157728  2016-09-22   RC-19960     Consumer  United States
# 9988  CA-2017-163629  2017-11-17   RA-19885    Corporate  United States
#
#        Regiao       ID_Produto        Categoria  \
# 3       South  FUR-TA-10000577        Furniture
# ...

# %% [markdown]
# Na instrução acima estamos filtrando o dataframe chamado df, retornando todas as linhas onde a coluna Quantidade for igual aos valores 5, 7, 9 ou 11. Passamos uma lista de valores como argumento para o método isin().
#
# Vamos deixar um pouquinho mais divertido. Se você executou a instrução acima, percebeu que foram retornadas 2.128 linhas. E se quisermos retornar somente 10 linhas? É só fatiar o resultado assim:

# %%
novo_df[novo_df['Quantidade'].isin([5,7,9,11])][:10]
# Out:
#          ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 3   US-2015-108966  2015-10-11   SO-20335     Consumer  United States
# 5   CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 9   CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 10  CA-2014-115812  2014-06-09   BH-11710     Consumer  United States
# 14  US-2015-118983  2015-11-22   HP-14815  Home Office  United States
# 21  CA-2016-137330  2016-12-09   KB-16585    Corporate  United States
# 22  CA-2016-137330  2016-12-09   KB-16585    Corporate  United States
# 27  US-2015-150630  2015-09-17   TB-21520     Consumer  United States
# 35  CA-2016-117590  2016-12-08   GH-14485    Corporate  United States
# 36  CA-2016-117590  2016-12-08   GH-14485    Corporate  United States
#
#      Regiao       ID_Produto        Categoria  \
# 3     South  FUR-TA-10000577        Furniture
# 5      West  FUR-FU-10001487        Furniture
# 9      West  OFF-AP-10002892  Office Supplies
# ...

# %%
novo_df[novo_df['Quantidade'].isin([5,7,9,11])][:10].shape
# Out:
# (10, 11)

# %% [markdown]
# ## Operadores Lógicos Para Manipulação de Dados com Pandas
#
# Os operadores lógicos são excelentes para filtrar dataframes e retornar exatamente os dados que precisamos para nosso trabalho. Para conhecer mais sobre as regras dos operadores lógicos, acesse aqui:
#
# https://pt.wikipedia.org/wiki/Operador_l%C3%B3gico

# %%
# Quero exibir apenas os membros da corporação

corporates = novo_df[(novo_df.Segmento == 'Corporate')]

corporates.head()
# Out:
#          ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais   Regiao  \
# 2   CA-2016-138688  2016-06-12   DV-13045  Corporate  United States     West
# 21  CA-2016-137330  2016-12-09   KB-16585  Corporate  United States  Central
# 22  CA-2016-137330  2016-12-09   KB-16585  Corporate  United States  Central
# 35  CA-2016-117590  2016-12-08   GH-14485  Corporate  United States  Central
# 36  CA-2016-117590  2016-12-08   GH-14485  Corporate  United States  Central
#
#          ID_Produto        Categoria  \
# 2   OFF-LA-10000240  Office Supplies
# 21  OFF-AR-10000246  Office Supplies
# 22  OFF-AP-10001492  Office Supplies
# 35  TEC-PH-10004977       Technology
# 36  FUR-FU-10003664        Furniture
#
#                                          Nome_Produto  Valor_Venda  Quantidade
# 2   Self-Adhesive Address Labels for Typewriters b...       14.620         2.0
# 21                                         Newell 318       19.460         7.0
# ...

# %% [markdown]
# ### Agora que consigo fazer consultar, podemos por operadores lógicos, tipo o AND

# %%
# Quero as vendas home office feitas no sul
vendas_home_office = novo_df[(novo_df.Regiao == 'South') & (novo_df.Segmento == "Home Office")]

vendas_home_office.head()
# Out:
#           ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais Regiao  \
# 182  CA-2014-158274  2014-11-19   RM-19675  Home Office  United States  South
# 183  CA-2014-158274  2014-11-19   RM-19675  Home Office  United States  South
# 184  CA-2014-158274  2014-11-19   RM-19675  Home Office  United States  South
# 231  US-2017-100930  2017-04-07   CS-12400  Home Office  United States  South
# 232  US-2017-100930  2017-04-07   CS-12400  Home Office  United States  South
#
#           ID_Produto   Categoria  \
# 182  TEC-PH-10003273  Technology
# 183  TEC-PH-10004896  Technology
# 184  TEC-AC-10002345  Technology
# 231  FUR-TA-10001705   Furniture
# 232  FUR-TA-10003473   Furniture
#
#                                          Nome_Produto  Valor_Venda  Quantidade
# 182                                      AT&T TR1909W     503.9600         4.0
# 183                        Nokia Lumia 521 (T-Mobile)     149.9500         5.0
# ...

# %% [markdown]
# ### Um exemplo usando o operador OR, onde preciso que apenas uma das condições seja verdadeira

# %%
vendas_home_office = novo_df[(novo_df.Regiao == 'South') | (novo_df.Segmento == "Home Office")]

vendas_home_office.head(30)
# Out:
#           ID_Pedido Data_Pedido ID_Cliente     Segmento           Pais  \
# 0    CA-2016-152156  2016-11-08   CG-12520     Consumer  United States
# 1    CA-2016-152156  2016-11-08   CG-12520     Consumer  United States
# 3    US-2015-108966  2015-10-11   SO-20335     Consumer  United States
# 4    US-2015-108966  2015-10-11   SO-20335     Consumer  United States
# 12   CA-2017-114412  2017-04-15   AA-10480     Consumer  United States
# 14   US-2015-118983  2015-11-22   HP-14815  Home Office  United States
# 15   US-2015-118983  2015-11-22   HP-14815  Home Office  United States
# 34   CA-2017-107727  2017-10-19   MA-17560  Home Office  United States
# 37   CA-2015-117415  2015-12-27   SN-20710  Home Office  United States
# 38   CA-2015-117415  2015-12-27   SN-20710  Home Office  United States
# 39   CA-2015-117415  2015-12-27   SN-20710  Home Office  United States
# 40   CA-2015-117415  2015-12-27   SN-20710  Home Office  United States
# ...

# %%
# head() = Primeiros elementos
# tail() = ultimos elementos
# sample() = Elementos em ordem aleatória

# %%
# Quero as vendas não feitas em home office feitas não feitas no sul
vendas_home_office = novo_df[(novo_df.Regiao != 'South') & (novo_df.Segmento != "Home Office")]

vendas_home_office.tail()
# Out:
#            ID_Pedido Data_Pedido ID_Cliente  Segmento           Pais Regiao  \
# 9986  CA-2016-125794  2016-09-29   ML-17410  Consumer  United States   West
# 9990  CA-2017-121258  2017-02-26   DB-13060  Consumer  United States   West
# 9991  CA-2017-121258  2017-02-26   DB-13060  Consumer  United States   West
# 9992  CA-2017-121258  2017-02-26   DB-13060  Consumer  United States   West
# 9993  CA-2017-119914  2017-05-04   CC-12220  Consumer  United States   West
#
#            ID_Produto        Categoria  \
# 9986  TEC-AC-10003399       Technology
# 9990  FUR-FU-10000747        Furniture
# 9991  TEC-PH-10003645       Technology
# 9992  OFF-PA-10004041  Office Supplies
# 9993  OFF-AP-10002684  Office Supplies
#
#                                            Nome_Produto  Valor_Venda  \
# 9986  Memorex Mini Travel Drive 64 GB USB 2.0 Flash ...       36.240
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...       91.960
# ...

# %% [markdown]
# ## Agrupamento de Dados em DataFrames com Group By
#
# A função Pandas Groupby é uma função versátil e fácil de usar que ajuda a obter uma visão geral dos dados. Isso torna mais fácil explorar o conjunto de dados e revelar os relacionamentos entre as variáveis.
#
# O código a seguir agrupará as linhas com base nas combinações Segmento/Regiao/Valor_Venda e nos dará a taxa média de vendas de cada grupo.

# %%
# Aplicamos o group by
novo_df[['Segmento', 'Regiao', 'Valor_Venda']].groupby(['Segmento', 'Regiao']).mean()
# Out:
#                      Valor_Venda
# Segmento    Regiao
# Consumer    Central   207.946728
#             East      238.875539
#             South     233.390180
#             West      217.033955
# Corporate   Central   234.763466
#             East      228.516929
#             South     238.992025
#             West      235.265911
# Home Office Central   208.248046
#             East      253.911805
#             South     272.996329
#             West      239.442692

# %% [markdown]
# Na instrução acima, primeiro filtramos os dados extraindo 3 colunas: ['Segmento','Regiao','Valor_Venda']. Na sequência, agrupamos por duas colunas: ['Segmento','Regiao']. E então calculamos a média para a coluna que ficou foram do group by, nesse caso a coluna Sales.
#
# O comportamento do group by com Pandas é o mesmo observado na Linguagem SQL.

# %% [markdown]
# ## Agregação Múltipla com Group By
#
# Observe que no exemplo acima é usado apenas uma função, a média. Mas podemos usar várias funções de agregação ao mesmo tempo. Veja o exemplo abaixo: usando a função agg().

# %%
novo_df[['Segmento', 'Regiao', 'Valor_Venda']].groupby(['Segmento', 'Regiao']).agg(['mean', 'std', 'count'])
# Out:
#                     Valor_Venda
#                            mean          std count
# Segmento    Regiao
# Consumer    Central  207.946728   587.906523  1212
#             East     238.875539   633.371169  1469
#             South    233.390180   559.346824   838
#             West     217.033955   551.997547  1672
# Corporate   Central  234.763466   818.947521   673
#             East     228.516929   530.001654   877
#             South    238.992025   586.176947   510
#             West     235.265911   471.288764   960
# Home Office Central  208.248046   371.009180   438
#             East     253.911805   722.777318   502
#             South    272.996329  1404.798466   272
#             West     239.442692   529.242737   571

# %% [markdown]
# ## Vamos trabalhar agora com o filtro do DataFrame do Pandas em Strings

# %%
novo_df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...

# %%
# Eu quero exbir strings do Segmento que comecem com Cor
novo_df[novo_df.Segmento.str.startswith("Cor")].head()
# Out:
#          ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais   Regiao  \
# 2   CA-2016-138688  2016-06-12   DV-13045  Corporate  United States     West
# 21  CA-2016-137330  2016-12-09   KB-16585  Corporate  United States  Central
# 22  CA-2016-137330  2016-12-09   KB-16585  Corporate  United States  Central
# 35  CA-2016-117590  2016-12-08   GH-14485  Corporate  United States  Central
# 36  CA-2016-117590  2016-12-08   GH-14485  Corporate  United States  Central
#
#          ID_Produto        Categoria  \
# 2   OFF-LA-10000240  Office Supplies
# 21  OFF-AR-10000246  Office Supplies
# 22  OFF-AP-10001492  Office Supplies
# 35  TEC-PH-10004977       Technology
# 36  FUR-FU-10003664        Furniture
#
#                                          Nome_Produto  Valor_Venda  Quantidade
# 2   Self-Adhesive Address Labels for Typewriters b...       14.620         2.0
# 21                                         Newell 318       19.460         7.0
# ...

# %%
# Eu quero exbir strings do Segmento que terminem com Ate
terminam_ate = novo_df[novo_df.Segmento.str.endswith("ate")]

terminam_ate.head()
# Out:
#          ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais   Regiao  \
# 2   CA-2016-138688  2016-06-12   DV-13045  Corporate  United States     West
# 21  CA-2016-137330  2016-12-09   KB-16585  Corporate  United States  Central
# 22  CA-2016-137330  2016-12-09   KB-16585  Corporate  United States  Central
# 35  CA-2016-117590  2016-12-08   GH-14485  Corporate  United States  Central
# 36  CA-2016-117590  2016-12-08   GH-14485  Corporate  United States  Central
#
#          ID_Produto        Categoria  \
# 2   OFF-LA-10000240  Office Supplies
# 21  OFF-AR-10000246  Office Supplies
# 22  OFF-AP-10001492  Office Supplies
# 35  TEC-PH-10004977       Technology
# 36  FUR-FU-10003664        Furniture
#
#                                          Nome_Produto  Valor_Venda  Quantidade
# 2   Self-Adhesive Address Labels for Typewriters b...       14.620         2.0
# 21                                         Newell 318       19.460         7.0
# ...

# %%
# Quero saber qual é o produto mais vendido
novo_df.Nome_Produto.value_counts().index[0]
# Out:
# 'Staple envelope'

# %% [markdown]
# ## Split de Strings em DataFrames do Pandas
#
# Com Pandas podemos realizar diversas tarefas de split de strings dividindo uma coluna ou extraindo elementos do nosso interesse. Vamos ao exemplo!

# %%
novo_df['ID_Pedido'].head()
# Out:
# 0    CA-2016-152156
# 1    CA-2016-152156
# 2    CA-2016-138688
# 3    US-2015-108966
# 4    US-2015-108966
# Name: ID_Pedido, dtype: object

# %% [markdown]
# Vemos um padrão: País - Ano - id

# %%
novo_df['ID_Pedido'].str.split('-')
# Out:
# 0       [CA, 2016, 152156]
# 1       [CA, 2016, 152156]
# 2       [CA, 2016, 138688]
# 3       [US, 2015, 108966]
# 4       [US, 2015, 108966]
#                ...
# 9989    [CA, 2014, 110422]
# 9990    [CA, 2017, 121258]
# 9991    [CA, 2017, 121258]
# 9992    [CA, 2017, 121258]
# 9993    [CA, 2017, 119914]
# Name: ID_Pedido, Length: 9994, dtype: object

# %%
# Quero pegar o ano
novo_df['ID_Pedido'].str.split('-').str[1]
# Out:
# 0       2016
# 1       2016
# 2       2016
# 3       2015
# 4       2015
#         ...
# 9989    2014
# 9990    2017
# 9991    2017
# 9992    2017
# 9993    2017
# Name: ID_Pedido, Length: 9994, dtype: object

# %%
# Quero criar a coluna ano
novo_df['Ano'] = novo_df['ID_Pedido'].str.split('-').str[1]

# %%
novo_df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade  \
# 0                  Bush Somerset Collection Bookcase     261.9600         3.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         3.0
# ...

# %% [markdown]
# ## Strip de Strings em DataFrames do Pandas
#
# Cuidado para não confundir. Vimos o Split e agora veremos o Strip. São funções diferentes.
#
# O Split divide a string. O Strip remove caracteres da string. Veja os exemplos.

# %%
novo_df['Data_Pedido'].head(3)
# Out:
# 0    2016-11-08
# 1    2016-11-08
# 2    2016-06-12
# Name: Data_Pedido, dtype: object

# %% [markdown]
# A coluna 'Data_Pedido' é a data de envio do produto no formato YYYY-MM-DD. Imagine que seja necessário deixar o ano apenas com 2 dígitos sem alterar o tipo da variável. Fazemos isso com a função lstrip(), ou seja, left strip.

# %%
# lstrip = Remover os elementos da esquerda
# rstrip = Remover os elementos da direita

novo_df['Data_Pedido'].str.lstrip('20')
# Out:
# 0       16-11-08
# 1       16-11-08
# 2       16-06-12
# 3       15-10-11
# 4       15-10-11
#           ...
# 9989    14-01-21
# 9990    17-02-26
# 9991    17-02-26
# 9992    17-02-26
# 9993    17-05-04
# Name: Data_Pedido, Length: 9994, dtype: object

# %% [markdown]
# Como não usamos o inplace = True a mudança é somente na memória e não altera o dataframe. Podemos usar ainda as funções rstrip() e strip() com diferentes variações de strip de strings.

# %%
novo_df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   CG-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade  \
# 0                  Bush Somerset Collection Bookcase     261.9600         NaN
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         NaN
# ...

# %% [markdown]
# ## Replace de Strings em DataFrames do Pandas
#
# Se for necessário substituir caracteres dentro de uma string o Pandas oferece uma função para isso também.
#
# Por exemplo, vamos substituir 2 caracteres em uma das colunas.

# %%
novo_df['ID_Cliente'] = novo_df['ID_Cliente'].str.replace('CG', 'DA')

# %%
novo_df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   DA-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   DA-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade  \
# 0                  Bush Somerset Collection Bookcase     261.9600         NaN
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         NaN
# ...

# %% [markdown]
# ## Combinação de Strings em DataFrames do Pandas
#
# A função cat() pode ser usada para concatenar strings em um dataframe do Pandas.
#
# Vamos criar uma nova coluna concatenando as colunas “ID_Pedido” e “Segmento” com o separador “-”.

# %%
novo_df['Pedido_Segmento'] = novo_df['ID_Pedido'].str.cat(novo_df['Segmento'], sep = '-')

# %%
novo_df.head()
# Out:
#         ID_Pedido Data_Pedido ID_Cliente   Segmento           Pais Regiao  \
# 0  CA-2016-152156  2016-11-08   DA-12520   Consumer  United States  South
# 1  CA-2016-152156  2016-11-08   DA-12520   Consumer  United States  South
# 2  CA-2016-138688  2016-06-12   DV-13045  Corporate  United States   West
# 3  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
# 4  US-2015-108966  2015-10-11   SO-20335   Consumer  United States  South
#
#         ID_Produto        Categoria  \
# 0  FUR-BO-10001798        Furniture
# 1  FUR-CH-10000454        Furniture
# 2  OFF-LA-10000240  Office Supplies
# 3  FUR-TA-10000577        Furniture
# 4  OFF-ST-10000760  Office Supplies
#
#                                         Nome_Produto  Valor_Venda  Quantidade  \
# 0                  Bush Somerset Collection Bookcase     261.9600         NaN
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...     731.9400         NaN
# ...

# %%
novo_df.plot()
# Out:
# <AxesSubplot:>
